# %% [markdown]
# # Assignment 2

# %% [markdown]
# ## Q1

# %%
rollNo = "1024170164"
L = [int(digit) * 10 for digit in rollNo]
print("Original L:", L)
L.append(203)
print("After append(203):", L)
L.insert(3, 155)
print("After insert(3, 155):", L)
L.remove(155)
print("After remove(155):", L)
L.pop()
print("After pop():", L)
L.sort()
print("Sorted ascending:", L)
L.sort(reverse = True)
print("Sorted descending:", L)
print("First three elements:", L[:3])
print("Last three elements:", L[-3:])
avg = sum(L) / len(L)
above_avg = [x for x in L if x > avg]
print("Average of L:", avg)
print("Elements greater than average:", above_avg)
# Out:
# Original L: [10, 0, 20, 40, 10, 70, 0, 10, 60, 40]
# After append(203): [10, 0, 20, 40, 10, 70, 0, 10, 60, 40, 203]
# After insert(3, 155): [10, 0, 20, 155, 40, 10, 70, 0, 10, 60, 40, 203]
# After remove(155): [10, 0, 20, 40, 10, 70, 0, 10, 60, 40, 203]
# After pop(): [10, 0, 20, 40, 10, 70, 0, 10, 60, 40]
# Sorted ascending: [0, 0, 10, 10, 10, 20, 40, 40, 60, 70]
# Sorted descending: [70, 60, 40, 40, 20, 10, 10, 10, 0, 0]
# First three elements: [70, 60, 40]
# Last three elements: [10, 0, 0]
# Average of L: 26.0
# Elements greater than average: [70, 60, 40, 40]

# %% [markdown]
# ## Q2

# %%
scores = tuple(L[:8])
print("scores tuple:", scores)
highest = max(scores)
highest_index = scores.index(highest)
lowest = min(scores)
lowest_count = scores.count(lowest)
print(f"Highest score: {highest} at index {highest_index}")
print(f"Lowest score: {lowest}, appears {lowest_count} time(s)")
reversed_scores = list(scores[::-1])
print("Reversed scores (as list):", reversed_scores)
user_score = int(input("Enter a score to search for: "))
if user_score in scores:
    print(f"{user_score} found at index {scores.index(user_score)}")
else:
    print(f"{user_score} not present in scores")
try:
    scores[0] = 100
except TypeError as e:
    print("Error caught:", e)
first_score, second_score, *remaining_scores = scores
print("First score:", first_score)
print("Second score:", second_score)
print("Remaining scores:", remaining_scores)
# Out:
# scores tuple: (70, 60, 40, 40, 20, 10, 10, 10)
# Highest score: 70 at index 0
# Lowest score: 10, appears 3 time(s)
# Reversed scores (as list): [10, 10, 10, 20, 40, 40, 60, 70]
# Enter a score to search for:  567
# 567 not present in scores
# Error caught: 'tuple' object does not support item assignment
# First score: 70
# Second score: 60
# Remaining scores: [40, 40, 20, 10, 10, 10]

# %% [markdown]
# ## Q3

# %%
import random 
from collections import Counter
rollNo = 1024170164
random.seed(rollNo)
numbers = [random.randint(100, 900) for _ in range(100)]
print("Generated numbers:", numbers)
odd_numbers = [n for n in numbers if n % 2 != 0]
print("Odd numbers count:", len(odd_numbers))
even_numbers = [n for n in numbers if n % 2 == 0]
print("Even numbers count:", len(even_numbers))
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

primes = [n for n in numbers if is_prime(n)]
print("Prime numbers count:", len(primes))
print("Prime numbers list:", primes)
counts = Counter(numbers)
most_common_num, freq = counts.most_common(1)[0]
print(f"Most frequent number: {most_common_num} (occurs {freq} times)")
# Out:
# Generated numbers: [763, 237, 114, 700, 187, 799, 463, 695, 335, 373, 318, 249, 734, 618, 223, 691, 123, 802, 286, 764, 654, 195, 759, 813, 314, 435, 900, 845, 820, 809, 361, 466, 233, 707, 427, 814, 509, 231, 755, 393, 159, 268, 751, 419, 246, 820, 160, 342, 133, 632, 610, 431, 430, 362, 293, 164, 270, 389, 283, 480, 360, 530, 499, 206, 184, 323, 530, 719, 202, 731, 478, 551, 884, 227, 478, 289, 157, 155, 450, 418, 556, 601, 727, 337, 524, 544, 750, 184, 281, 460, 550, 319, 275, 145, 584, 242, 802, 468, 297, 637]
# Odd numbers count: 52
# Even numbers count: 48
# Prime numbers count: 21
# Prime numbers list: [463, 373, 223, 691, 809, 233, 509, 751, 419, 431, 293, 389, 283, 499, 719, 227, 157, 601, 727, 337, 281]
# Most frequent number: 802 (occurs 2 times)

# %% [markdown]
# ## Q4

# %%
digits = [1, 0, 2, 4, 1, 7, 0, 1]
A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}
print('Set A : ', A)
print('Set B : ', B)
union_AB  = A | B
print('Union(A, B) : ', union_AB)
intersection_AB = A & B
print('Intersection (A, B) : ', intersection_AB)
A_minus_B = A.difference(B)
B_minus_A = B.difference(A)
print('A - B : ', A_minus_B)
print('B - A : ', B_minus_A)
print("Note: difference() gives elements in one set but not the other (one direction at a time),")
print("while symmetric_difference() gives elements in either set but NOT in both (combines both directions).")
sym_diff = A.symmetric_difference(B)
print('Symmetric difference(A, B) : ', sym_diff)
is_subset = A.issubset(B)
is_superset = B.issuperset(A)
print("Is A a subset of B?", is_subset)
print("Is B a superset of A?", is_superset)
X = int(input("Enter a value X to remove from set A: "))
A.discard(X)
print("Set A after discard():", A)
print("discard() is safer than remove() because discard() does nothing if X is not in the set,")
print("while remove() raises a KeyError, potentially crashing the program.")
# Out:
# Set A :  {0, 7, 14, 49, 28}
# Set B :  {0, 36, 9, 18, 63}
# Union(A, B) :  {0, 36, 7, 9, 14, 49, 18, 28, 63}
# Intersection (A, B) :  {0}
# A - B :  {49, 28, 14, 7}
# B - A :  {9, 18, 36, 63}
# Note: difference() gives elements in one set but not the other (one direction at a time),
# while symmetric_difference() gives elements in either set but NOT in both (combines both directions).
# Symmetric difference(A, B) :  {7, 9, 14, 18, 28, 36, 49, 63}
# Is A a subset of B? False
# Is B a superset of A? False
# Enter a value X to remove from set A:  89
# Set A after discard(): {0, 7, 14, 49, 28}
# discard() is safer than remove() because discard() does nothing if X is not in the set,
# while remove() raises a KeyError, potentially crashing the program.

# %% [markdown]
# ## Q5

# %%
my_dict = {
"name": "Kanan",
"roll_no": "1024170164",
"branch": "COPC",
"age": 20,
"city": "Sirsa"
}
my_dict["location"] = my_dict.pop("city")
my_dict["cgpa"] = 9.17
my_dict["age"] += 1
dict_pop = my_dict.copy()
popped_value = dict_pop.pop("branch")
print("dict after pop('branch'):", dict_pop)
print("pop() returned the removed value:", popped_value)
dict_del = my_dict.copy()
del dict_del["branch"]
print("dict after del dict['branch']:", dict_del)
print("pop() returns the value it removes (usable in your code), while del just deletes the key and returns nothing.")
for key, value in my_dict.items():
    print(f"{key} → {value}")
if "email" in my_dict:
    print("Email:", my_dict["email"])
else:
    print("'email' key not found in dictionary — no email on record.")
friend_dict = {
"name": "Sam",
"roll_no": "1024170165",
"branch": "COPC",
"age": 19,
"city": "UP"
}
merged = {**my_dict, **friend_dict}
print("Merged dictionary:", merged)
print("When both dicts share a key, the value from the dictionary listed LAST (friend_dict here) wins/overwrites.")
string_only = {k: v for k, v in my_dict.items() if isinstance(v, str)}
print("Dictionary with only string values:", string_only)
# Out:
# dict after pop('branch'): {'name': 'Kanan', 'roll_no': '1024170164', 'age': 21, 'location': 'Sirsa', 'cgpa': 9.17}
# pop() returned the removed value: COPC
# dict after del dict['branch']: {'name': 'Kanan', 'roll_no': '1024170164', 'age': 21, 'location': 'Sirsa', 'cgpa': 9.17}
# pop() returns the value it removes (usable in your code), while del just deletes the key and returns nothing.
# name → Kanan
# roll_no → 1024170164
# branch → COPC
# age → 21
# location → Sirsa
# cgpa → 9.17
# 'email' key not found in dictionary — no email on record.
# Merged dictionary: {'name': 'Sam', 'roll_no': '1024170165', 'branch': 'COPC', 'age': 19, 'location': 'Sirsa', 'cgpa': 9.17, 'city': 'UP'}
# When both dicts share a key, the value from the dictionary listed LAST (friend_dict here) wins/overwrites.
# Dictionary with only string values: {'name': 'Kanan', 'roll_no': '1024170164', 'branch': 'COPC', 'location': 'Sirsa'}
